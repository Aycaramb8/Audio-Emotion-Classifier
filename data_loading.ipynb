# %% [markdown]
# # Load Data

# %% [markdown]
# Note: Some datasets can be downloaded manually while some are done by using kagglehub. Files are moved to ./data manually.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ejlok1/toronto-emotional-speech-set-tess")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 428M/428M [00:09<00:00, 45.6MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Thunderup\.cache\kagglehub\datasets\ejlok1\toronto-emotional-speech-set-tess\versions\1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ejlok1/surrey-audiovisual-expressed-emotion-savee")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 107M/107M [00:02<00:00, 40.8MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Thunderup\.cache\kagglehub\datasets\ejlok1\surrey-audiovisual-expressed-emotion-savee\versions\1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("piyushagni5/berlin-database-of-emotional-speech-emodb")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 38.0M/38.0M [00:01<00:00, 25.7MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Thunderup\.cache\kagglehub\datasets\piyushagni5\berlin-database-of-emotional-speech-emodb\versions\1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sourabhy/emovo-italian-ser-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 241M/241M [00:10<00:00, 25.0MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Thunderup\.cache\kagglehub\datasets\sourabhy\emovo-italian-ser-dataset\versions\1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("uwrfkaggler/ravdess-emotional-song-audio")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 456M/456M [00:19<00:00, 24.2MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Thunderup\.cache\kagglehub\datasets\uwrfkaggler\ravdess-emotional-song-audio\versions\1
