# %% [markdown]
# # Process Self Collected Data

# %% [markdown]
# ## Convert mp4 files to audio file (wav)

# %%
import subprocess
from pathlib import Path
import shutil

# %% [markdown]
# ### ENG ver

# %%
mp4_dir = Path("./data/reallife/mp4/ENG")
wav_dir = Path("./data/reallife/wav/ENG")

if wav_dir.exists():
    shutil.rmtree(wav_dir)
    
wav_dir.mkdir(parents=True, exist_ok=True)

for mp4_file in mp4_dir.glob("*.mp4"):
    
    wav_file = wav_dir / (mp4_file.stem + ".wav")
    
    cmd = [
        "ffmpeg",
        "-i", str(mp4_file),
        "-ac", "1",          # mono
        "-ar", "48000",      # sample rate
        "-vn",               # ignore video
        "-y",
        str(wav_file)
    ]

    subprocess.run(cmd)
    print(f"Converted {mp4_file.name}")
# Out:
# Converted Chandler_angry_male_1.mp4
# Converted Chandler_angry_male_10.mp4
# Converted Chandler_angry_male_2.mp4
# Converted Chandler_angry_male_3.mp4
# Converted Chandler_angry_male_4.mp4
# Converted Chandler_angry_male_5.mp4
# Converted Chandler_angry_male_6.mp4
# Converted Chandler_angry_male_7.mp4
# Converted Chandler_angry_male_8.mp4
# Converted Chandler_angry_male_9.mp4
# Converted Chandler_disgust_male_1.mp4
# Converted Chandler_disgust_male_10.mp4
# Converted Chandler_disgust_male_2.mp4
# Converted Chandler_disgust_male_3.mp4
# Converted Chandler_disgust_male_4.mp4
# Converted Chandler_disgust_male_5.mp4
# Converted Chandler_disgust_male_6.mp4
# Converted Chandler_disgust_male_7.mp4
# Converted Chandler_disgust_male_8.mp4
# Converted Chandler_disgust_male_9.mp4
# Converted Chandler_fear_male_1.mp4
# Converted Chandler_fear_male_10.mp4
# Converted Chandler_fear_male_2.mp4
# Converted Chandler_fear_male_3.mp4
# Converted Chandler_fear_male_4.mp4
# ...

# %% [markdown]
# ### CHI ver

# %%
mp4_dir = Path("./data/reallife/mp4/CHI")
wav_dir = Path("./data/reallife/wav/CHI")

if wav_dir.exists():
    shutil.rmtree(wav_dir)
    
wav_dir.mkdir(parents=True, exist_ok=True)

for mp4_file in mp4_dir.glob("*.mp4"):
    
    wav_file = wav_dir / (mp4_file.stem + ".wav")
    
    cmd = [
        "ffmpeg",
        "-i", str(mp4_file),
        "-ac", "1",          # mono
        "-ar", "48000",      # sample rate
        "-vn",               # ignore video
        "-y",
        str(wav_file)
    ]

    subprocess.run(cmd)
    print(f"Converted {mp4_file.name}")
# Out:
# Converted 关谷神奇_angry_male_1.mp4
# Converted 关谷神奇_angry_male_2.mp4
# Converted 关谷神奇_angry_male_3.mp4
# Converted 关谷神奇_disgust_male_1.mp4
# Converted 关谷神奇_fear_male_1.mp4
# Converted 关谷神奇_fear_male_2.mp4
# Converted 关谷神奇_fear_male_3.mp4
# Converted 关谷神奇_happy_male_1.mp4
# Converted 关谷神奇_neutral_male_1.mp4
# Converted 关谷神奇_neutral_male_10.mp4
# Converted 关谷神奇_neutral_male_11.mp4
# Converted 关谷神奇_neutral_male_12.mp4
# Converted 关谷神奇_neutral_male_13.mp4
# Converted 关谷神奇_neutral_male_14.mp4
# Converted 关谷神奇_neutral_male_15.mp4
# Converted 关谷神奇_neutral_male_16.mp4
# Converted 关谷神奇_neutral_male_17.mp4
# Converted 关谷神奇_neutral_male_18.mp4
# Converted 关谷神奇_neutral_male_19.mp4
# Converted 关谷神奇_neutral_male_2.mp4
# Converted 关谷神奇_neutral_male_20.mp4
# Converted 关谷神奇_neutral_male_21.mp4
# Converted 关谷神奇_neutral_male_22.mp4
# Converted 关谷神奇_neutral_male_23.mp4
# Converted 关谷神奇_neutral_male_3.mp4
# Converted 关谷神奇_neutral_male_4.mp4
# Converted 关谷神奇_neutral_male_5.mp4
# ...
